# %%
from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON
from dateutil import parser
import isodate
import seaborn as sns 
import matplotlib.pyplot as  plt

# %%
api_key_project1 = "AIzaSyC4GI7hURrd-kSVurCxNy1iO8BTyP1IH6U"
id_channel = ["UCN7x37T8InfV3DINfYKvOQQ"]

# %%
api_service_name = "youtube"
api_version = "v3"
youtube = build(api_service_name, api_version, developerKey = api_key_project1)

# %%
request = youtube.channels().list(
        part = "snippet,contentDetails,statistics",
        id= ','.join(id_channel)
        )
response = request.execute()

JSON(response)

# %%
def get_channel_stats(youtube,channel_ids):
    all_data = []

    request = youtube.channels().list(
        part = "snippet,contentDetails,statistics",
        id= ','.join(id_channel)
        )
    response = request.execute()

    #loop through items (if you need more than 1 channel)
    for item in response["items"]:
        data = {"channelName": item["snippet"]["title"],
                "subscribers": item["statistics"]["subscriberCount"],
                "views": item["statistics"]["viewCount"],
                "totalVideos": item["statistics"]["videoCount"],
                "playlistId": item["contentDetails"]["relatedPlaylists"]["uploads"]
               }
        all_data.append(data)
    return(pd.DataFrame(all_data))

# %%
channel_stats = get_channel_stats(youtube,id_channel)
channel_stats
# Out:
#        channelName subscribers      views totalVideos  \
# 0  Michele Molteni     1470000  220117656         364
#
#                  playlistId
# 0  UUN7x37T8InfV3DINfYKvOQQ

# %%
playlistId = "UUN7x37T8InfV3DINfYKvOQQ"

# %%
def get_videos_id(youtube,playlistId):

    videosIdList = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlistId,
        maxResults = 50
        )
    response = request.execute()

    for item in response["items"]:
        videoId = item["contentDetails"]["videoId"]
        videosIdList.append(videoId)
    next_page_token = response.get("nextPageToken")
    while next_page_token is not None:
        request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=playlistId,
            maxResults = 50,
            pageToken = next_page_token
            )
        response = request.execute()

        for item in response["items"]:
            videoId = item["contentDetails"]["videoId"]
            videosIdList.append(videoId)
        next_page_token = response.get("nextPageToken")
    return(videosIdList)

# %%
videosIDs = get_videos_id(youtube,playlistId)
len(videosIDs)
# Out:
# 364

# %%
def get_video_details(youtube, video_ids):
    all_video_info = []
    
    request = youtube.videos().list(
        part="snippet, contentDetails,statistics",
        id = videosIDs[0:50]
        )
    response = request.execute()
    for item in response["items"]:
        stats_to_keep = {"snippet":["channelTitle","title","description","tags","publishedAt"],
                         "statistics":["viewCount","likeCount","favouriteCount","commentCount"],
                         "contentDetails":["duration","caption"]
                        }
        video_info = {}
        video_info["video_id"] = item["id"]
        for k in stats_to_keep.keys():
            for v in stats_to_keep[k]:
                try:
                    video_info[v] = item[k][v]
                except:
                    video_info[v] = None
                
                
    
        all_video_info.append(video_info)
    return pd.DataFrame(all_video_info)

# %%
df_video = get_video_details(youtube, videosIDs)
df_video
# Out:
#        video_id     channelTitle  \
# 0   sqJiwNxq5ho  Michele Molteni
# 1   -ULamjQoqIg  Michele Molteni
# 2   XtFH7BRPnSM  Michele Molteni
# 3   uy6wDiGNKoQ  Michele Molteni
# 4   w5xrD8R32zE  Michele Molteni
# 5   eQPhBvWAff4  Michele Molteni
# 6   gJqEX0q-4bQ  Michele Molteni
# 7   9WGQJrWBZvY  Michele Molteni
# 8   l-CCWYcV6uU  Michele Molteni
# 9   Rvv8gG0LfbA  Michele Molteni
# 10  XsVmHeAlgTo  Michele Molteni
# 11  OBPqMu4b6rM  Michele Molteni
# 12  qsEYCRTg0tY  Michele Molteni
# 13  qbUrMnaNZoc  Michele Molteni
# 14  ziBYuHVabfE  Michele Molteni
# 15  O0sFmH4ss5M  Michele Molteni
# 16  Trgs658_1Sc  Michele Molteni
# 17  zkpySdVxL_M  Michele Molteni
# 18  V2HLezcIs0A  Michele Molteni
# 19  bJlREafylck  Michele Molteni
# 20  DxMR0QbotZA  Michele Molteni
# 21  FfmHzQ95hcs  Michele Molteni
# 22  -XkjBaLL_iA  Michele Molteni
# 23  pk5Oi7LVSe8  Michele Molteni
# 24  iyVCzG5j41E  Michele Molteni
# 25  Tofj1Yr6ruY  Michele Molteni
# 26  37o8JgJG3UU  Michele Molteni
# 27  -hY5_KUt41M  Michele Molteni
# 28  x7bpVubwM18  Michele Molteni
# 29  mJl8xy11jlI  Michele Molteni
# 30  gzvNn7m184k  Michele Molteni
# 31  bRFtfG5hc_s  Michele Molteni
# 32  pFzsR8BpE6Y  Michele Molteni
# 33  qLAfeEqUOak  Michele Molteni
# 34  QzPFsozOSB8  Michele Molteni
# 35  ByyVSPEOse8  Michele Molteni
# 36  conNjXpC4hc  Michele Molteni
# 37  lDteEL_P7eQ  Michele Molteni
# 38  qNfbwEHxMOA  Michele Molteni
# 39  j703-JgSfcY  Michele Molteni
# 40  dVyb1sBeU4o  Michele Molteni
# 41  R2pYRIX-VL4  Michele Molteni
# 42  89c-YzmVMHE  Michele Molteni
# 43  n54GssY5sc0  Michele Molteni
# 44  ST4LNg9HpHk  Michele Molteni
# 45  tpA8GCdBFRk  Michele Molteni
# 46  AE9xI6SPx8o  Michele Molteni
# 47  8xjkUYX71DY  Michele Molteni
# 48  23cUVUS-JTM  Michele Molteni
# 49  Xkb7KTD3TZ4  Michele Molteni
#
#                                                 title  \
# 0                   COSTRUISCO IL MEGA BUNKER - EP.13
# 1            RICOSTRUISCO IL GIARDINO DEL MEGA STUDIO
# 2                   COSTRUISCO IL MEGA BUNKER - EP.12
# 3                   COSTRUISCO IL MEGA BUNKER - EP.11
# 4         HO COSTRUITO IL TAVOLO DI MUSCHIO SELVAGGIO
# 5   COSTRUISCO UNA METROPOLITANA NEL MIO GIARDINO ...
# 6             HO COMPRATO 500.000 EURO DI MEGA STUDIO
# 7          HO PROVATO A CREARE CARTA DALLA SPAZZATURA
# 8   COSTRUISCO UNA METROPOLITANA NEL MIO GIARDINO ...
# 9            HO TESTATO LE SCARPE PIU VELOCI AL MONDO
# 10                  COSTRUISCO IL MEGA BUNKER - EP.10
# 11  COSTRUISCO UNA METROPOLITANA NEL MIO GIARDINO ...
# 12                     COSTRUISCO UN GO KART A MOTORE
# 13                 COSTRUISCO UNA MINI BARCA A MOTORE
# 14                       IL COSTOSO FUTURO DEL CANALE
# 15                    HO COSTRUITO UN'OFFICINA MOBILE
# 16         COSTRUISCO LA GRU LEGO PIU GRANDE AL MONDO
# 17                 PASSO 24 ORE IN UNA TORRE DEL 1800
# 18                   COSTRUISCO IL MEGA BUNKER - EP.9
# 19                   HO PRESO UN MEGA MOTORE AD ELICA
# 20                   COMPLETO LA MINI CASA SULL' AUTO
# 21          ECCO QUANTO SPENDO PER LE MIE COSTRUZIONI
# 22                   COSTRUISCO IL MEGA BUNKER - EP.8
# 23                 COSTRUISCO UNA MINI CASA SULL'AUTO
# 24                   COSTRUISCO IL MEGA BUNKER - EP.7
# 25          ENTRO NELLA CASA SULL'ALBERO UN ANNO DOPO
# 26                 COSTRUISCO UNA MINI VILLA PER CANI
# 27                  CHE FINE FANNO LE MIE COSTRUZIONI
# 28          QUANTO HO GUADAGNATO CON YOUTUBE NEL 2023
# 29                   COSTRUISCO IL MEGA BUNKER - EP.6
# 30           HO COSTRUITO UNA GAMING ROOM NELLA PANDA
# 31      INIZIO IL NUOVO STUDIO CON PACCHI BLACKFRIDAY
# 32                   COSTRUISCO IL MEGA BUNKER - EP.5
# 33                    HO COSTRUITO IL MIO PRIMO GIOCO
# 34               IL MIO NUOVO APPARTAMENTO IN AFFITTO
# 35         HO COSTRUITO UNA STANZA SEGRETA INVISIBILE
# 36                   COSTRUISCO IL MEGA BUNKER - EP.4
# 37       HO PROVATO LA SUITE PRESIDENZIALE DI FIRENZE
# 38                   COSTRUISCO IL MEGA BUNKER - EP.3
# 39                        MINI ROULOTTE - COMPLETATA!
# 40             DENTRO AL CANYON PIU PROFONDO D'EUROPA
# 41                TRASFORMO IL MINI BUNKER IN PISCINA
# 42                     HO COSTRUITO UNA MINI ROULOTTE
# 43                   COSTRUISCO IL MEGA BUNKER - EP.2
# 44                      PROVO 1€ VS 20.000€ DI GADGET
# 45                    HO COSTRUITO UN ORTO AUTOMATICO
# 46                   MONTAGNE RUSSE - LA PROVA FINALE
# 47                   COSTRUISCO IL MEGA BUNKER - EP.1
# 48                   HO COSTRUITO UNA MINI AUTOMOBILE
# 49                        APRO 12 MILA EURO DI PACCHI
#
#                                           description  \
# 0   Scopri subito NordVPN: https://nordvpn.com/mol...
# 1   In collaborazione con Erion WEEE: https://erio...
# 2   Scarica Revolut gratis con il mio link per ric...
# 3   Scopri subito NordVPN: https://nordvpn.com/mol...
# 4   Con Boolean lanci la tua carriera tech. 200€ d...
# 5   Ricevi €20 di bonus quando scarichi Revolut GR...
# 6   Ottieni anche tu il 3,50% Lordo all'anno con T...
# 7   Prova le custodie Mobilfox: https://it.mobilfo...
# 8   Scopri subito NordVPN: https://nordvpn.com/mol...
# 9   Scopri air up al link https://airup.link/45Xcu...
# 10  Ricevi €20 di bonus quando scarichi Revolut GR...
# 11  Ottieni anche tu il 3,75% Lordo all'anno con T...
# 12  Con Boolean, diventi Web Developer in 6 mesi e...
# 13  Ecco come funziona il concorso: \n\n1 - Acquis...
# 14  Registrati su Young Platform Exchange e ricevi...
# 15  Ottieni anche tu il 3,75% Lordo all'anno con T...
# 16  Ho costruito la GRU LIEBHERR LR13000 della LEG...
# 17  Scopri subito NordVPN: https://nordvpn.com/mol...
# 18  Ricevi €20 di bonus quando scarichi Revolut GR...
# 19  PROVA SUBITO World of Warships: https://wo.ws/...
# 20  Scopri air up https://airup.link/3TtihXd E con...
# 21  Registrati su Young Platform Exchange e ricevi...
# 22  Scopri subito NordVPN: https://nordvpn.com/mol...
# 9     967469     43618           None          798  PT10M43S   false
# 10   2037062    101314           None         1985     PT17M   false
# 11   1448101    180071           None         2186  PT14M37S   false
# 12   1019114     49581           None         1185  PT16M11S   false
# 13   1435251     62159           None         1723  PT19M44S   false
# 14    679566     51468           None          948  PT11M31S   false
# 15   1194205     61623           None         1546  PT20M15S   false
# 16    987016     46024           None          734   PT15M3S   false
# 17    847566     39927           None          707   PT14M4S   false
# 18   1776909     93850           None         1745     PT18M   false
# 19    638116     34880           None          672  PT11M56S   false
# 20   1707262     77810           None         1731  PT21M33S   false
# 21    567645     38820           None          666  PT13M49S   false
# 22   1687083    184256           None         1469  PT16M30S   false
# 23   1192650     63701           None         1036  PT15M15S   false
# 24   1678409    117313           None         1375     PT17M   false
# 25   1292878     64763           None          932  PT10M54S   false
# 26   1952745    121113           None        16198   PT14M3S   false
# 27   1371918     55345           None          718  PT13M52S   false
# 28    910528     60603           None         1776  PT11M48S   false
# 29   2104036    182100           None         2306  PT21M49S   false
# 30   2124157     76660           None         1393  PT14M43S   false
# 31    925145     44424           None          715  PT18M25S   false
# 32   1880955     99447           None         1366   PT19M5S   false
# 33    707870     51914           None         1044  PT10M37S   false
# 34    950262     57280           None         1176  PT10M35S   false
# 35   1778599     81568           None         1473   PT17M2S   false
# 36   2280596    125926           None         1923   PT13M8S   false
# 37    913101     39296           None          661  PT12M31S   false
# 38   1805302    129152           None         1926  PT13M11S   false
# 39   2118322     89396           None         2857  PT14M13S   false
# 40    742044     37931           None         1038   PT12M6S   false
# 41   2384354    103145           None         1972  PT13M25S   false
# 42   1825234     88069           None         1993  PT16M34S   false
# 43   2811841    327448           None         3596  PT14M22S   false
# 44   1567158     76612           None         1122  PT16M17S   false
# 45   1905262    103836           None         2433   PT14M2S   false
# 46   2077909    124041           None         2132  PT16M13S   false
# 47   2791823    329828           None         7175  PT12M44S   false
# 48   1799455     75909           None         1317  PT13M41S   false
# 49   1229738     47569           None          790  PT15M45S   false

# %%
df_video.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags              False
# publishedAt       False
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount      False
# duration          False
# caption           False
# dtype: bool

# %%
df_video.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# caption           object
# dtype: object

# %%
# trasformo le colonne numeriche
numeric_cols = ["viewCount","likeCount","favouriteCount","commentCount"]
df_video[numeric_cols] = df_video[numeric_cols].apply(pd.to_numeric, errors = "coerce", axis = 1)

# %%
# modifico formattazzione della data di pubblicazione e creo giorno settimana
df_video["publishedAt"] = df_video["publishedAt"].apply(lambda x: parser.parse(x))
df_video["publishDayName"] = df_video["publishedAt"].apply(lambda x: x.strftime("%A"))
df_video[["publishedAt","publishDayName"]]
# Out:
#                  publishedAt publishDayName
# 0  2024-12-05 16:02:40+00:00       Thursday
# 1  2024-11-28 12:30:00+00:00       Thursday
# 2  2024-11-14 12:30:33+00:00       Thursday
# 3  2024-11-05 12:30:49+00:00        Tuesday
# 4  2024-10-10 11:30:39+00:00       Thursday
# 5  2024-09-30 11:30:23+00:00         Monday
# 28   0 days 00:11:48
# 29   0 days 00:21:49
# 30   0 days 00:14:43
# 31   0 days 00:18:25
# 32   0 days 00:19:05
# 33   0 days 00:10:37
# 34   0 days 00:10:35
# 35   0 days 00:17:02
# 36   0 days 00:13:08
# 37   0 days 00:12:31
# 38   0 days 00:13:11
# 39   0 days 00:14:13
# 40   0 days 00:12:06
# 41   0 days 00:13:25
# 42   0 days 00:16:34
# 43   0 days 00:14:22
# 44   0 days 00:16:17
# 45   0 days 00:14:02
# 46   0 days 00:16:13
# 47   0 days 00:12:44
# 48   0 days 00:13:41
# 49   0 days 00:15:45
# Name: durationSecs, dtype: timedelta64[ns]

# %%
# trasformo durata in secondi
df_video["durationSecs"] = df_video["durationSecs"].dt.total_seconds()
df_video["durationSecs"]
# Out:
# 0     1226.0
# 1      997.0
# 2     1320.0
# 3     1260.0
# 4      656.0
# 5      796.0
# 6      956.0
# 7      833.0
# 8     1005.0
# 9      643.0
# 10    1020.0
# 11     877.0
# 12     971.0
# 13    1184.0
# 14     691.0
# 15    1215.0
# 16     903.0
# 17     844.0
# 18    1080.0
# 19     716.0
# 20    1293.0
# 21     829.0
# 22     990.0
# 23     915.0
# 24    1020.0
# 25     654.0
# 26     843.0
# 27     832.0
# 28     708.0
# 29    1309.0
# 30     883.0
# 31    1105.0
# 32    1145.0
# 33     637.0
# 34     635.0
# 35    1022.0
# 36     788.0
# 37     751.0
# 38     791.0
# 39     853.0
# 40     726.0
# 41     805.0
# 42     994.0
# 43     862.0
# 44     977.0
# 45     842.0
# 46     973.0
# 47     764.0
# 48     821.0
# 49     945.0
# Name: durationSecs, dtype: float64

# %%
df_video["tagCount"] = df_video["tags"].apply(lambda x: 0 if x is None else len(x))
df_video["tagCount"]
# Out:
# 0     11
# 1      8
# 2      9
# 3      9
# 4      7
# 5     14
# 6      7
# 7      4
# 8     14
# 9      7
# 10     9
# 11    14
# 12    10
# 13    11
# 14     6
# 15    10
# 16     9
# 17    10
# 18     6
# 19     9
# 20     7
# 21    22
# 22     8
# 23     1
# 24     8
# 25     1
# 26     5
# 27     1
# 28    29
# 29    10
# 30     7
# 31     1
# 32     9
# 33     7
# 34     5
# 35     9
# 36     6
# 37    12
# 38    12
# 39    10
# 40    11
# 41    13
# 42    13
# 43    12
# 44    12
# 45    11
# 46     8
# 47     8
# 48    16
# 49    15
# Name: tagCount, dtype: int64

# %%
ax = sns.barplot(x='title', y='viewCount' , data = df_video.sort_values(
    'viewCount',
    ascending = False)[0:19]
                )
plot = ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

import matplotlib.ticker as ticker  
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000)+'K'))
# Out:
# C:\Users\lollo\AppData\Local\Temp\ipykernel_648\119113495.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plot = ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %%
plot = sns.violinplot(data = df_video, y = df_video["viewCount"], orient = "o")
plot.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000)+'K'))

# %%
fig,ax = plt.subplots(1,2)
sns.scatterplot(data = df_video, x = "commentCount", y = "viewCount", ax = ax[0])
sns.scatterplot(data = df_video, x = "likeCount", y = "viewCount", ax = ax[1])
# Out:
# <Axes: xlabel='likeCount', ylabel='viewCount'>

# %%
sns.histplot(data = df_video, x = "durationSecs", bins = 30)
# Out:
# <Axes: xlabel='durationSecs', ylabel='Count'>
